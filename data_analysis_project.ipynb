# %%
# importing selenium library

# %%
pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# ...

# %%
from selenium import webdriver
import pandas as pd

# %%
pip install requests beautifulsoup4

# %% [markdown]
# extracting main section

# %%
import requests
from bs4 import BeautifulSoup

def scrape_wikipedia(url):
    # Send a GET request to the Wikipedia page
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the main sections' titles
        main_sections = soup.find_all('span', {'class': 'mw-headline'})
        section_titles = [section.text for section in main_sections]

        return section_titles
    else:
        # If the request was not successful, print an error message
        print(f"Error: Unable to fetch the page. Status code: {response.status_code}")
        return None

# Example usage
if __name__ == "__main__":
    wikipedia_url = 'https://en.wikipedia.org/wiki/Nikola_Tesla'

    # Run the scraping function
    sections = scrape_wikipedia(wikipedia_url)

    # Print the extracted section titles
    if sections:
        print("Main Sections:")
        for title in sections:
            print(f"- {title}")
    else:
        print("Scraping failed.")
# Out:
# Main Sections:
# - Early years
# - Working at Budapest Telephone Exchange
# - Working at Edison
# - Moving to the United States
# - Tesla Electric Light & Manufacturing
# - AC and the induction motor
# - Market turmoil
# - New York laboratories
# - Tesla coil
# - Citizenship
# - Wireless lighting
# - Polyphase system and the Columbian Exposition
# - Steam-powered oscillating generator
# - Consulting on Niagara
# - The Nikola Tesla Company
# - Lab fire
# - X-ray experimentation
# - Radio remote control
# - Wireless power
# - Colorado Springs
# - Wardenclyffe
# - Later years
# - Bladeless turbine
# - Wireless lawsuits
# - Nobel Prize rumors
# - Other awards, patents and ideas
# - Living circumstances
# - Birthday press conferences
# - Death
# - Estate
# - Patents
# - Personal life and character
# - Appearance
# - Eidetic memory
# - Relationships
# - Sleep habits
# - Work and dining habits
# - Views and beliefs
# - On experimental and theoretical physics
# - On society
# - On religion
# ...

# %% [markdown]
# funtion to create dataframe

# %%
import pandas as pd

# %%
def create_dataframe(data):
    df = pd.DataFrame(data, columns=['Section Titles'])
    return df

# %%
 if sections:
        # Load the data into a Pandas DataFrame
        df = create_dataframe(sections)

# %%
print(df)
# Out:
#                                    Section Titles
# 0                                     Early years
# 1          Working at Budapest Telephone Exchange
# 2                               Working at Edison
# 3                     Moving to the United States
# 4            Tesla Electric Light & Manufacturing
# 5                      AC and the induction motor
# 6                                  Market turmoil
# 7                           New York laboratories
# 8                                      Tesla coil
# 9                                     Citizenship
# 10                              Wireless lighting
# 11  Polyphase system and the Columbian Exposition
# 12            Steam-powered oscillating generator
# 13                          Consulting on Niagara
# 14                       The Nikola Tesla Company
# 15                                       Lab fire
# 16                          X-ray experimentation
# 17                           Radio remote control
# ...

# %% [markdown]
# extracting paragraph

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_wikipedia_paragraphs(url):
    # Send a GET request to the Wikipedia page
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract all paragraphs from the page
        paragraphs = soup.find_all('p')
        paragraph_texts = [paragraph.text for paragraph in paragraphs]

        return paragraph_texts
    else:
        # If the request was not successful, print an error message
        print(f"Error: Unable to fetch the page. Status code: {response.status_code}")
        return None

# Load the extracted data into a Pandas DataFrame
def create_dataframe(data):
    df = pd.DataFrame(data, columns=['Paragraphs'])
    return df

# Example usage
if __name__ == "__main__":
    # Replace 'https://en.wikipedia.org/wiki/Python_(programming_language)' with the desired Wikipedia page URL
    wikipedia_url = 'https://en.wikipedia.org/wiki/Nikola_Tesla'

    # Run the scraping function
    paragraphs = scrape_wikipedia_paragraphs(wikipedia_url)

    if paragraphs:
        # Load the data into a Pandas DataFrame
        df = create_dataframe(paragraphs)

        # Print the DataFrame
        print("DataFrame:")
        print(df)
    else:
        print("Scraping failed.")
# Out:
# DataFrame:
#                                             Paragraphs
# 0                                                   \n
# 1    Nikola Tesla (/ˈtɛslə/; Serbian Cyrillic: Нико...
# 2    Born and raised in the Austrian Empire, Tesla ...
# 3    Attempting to develop inventions he could pate...
# 4    After Wardenclyffe, Tesla experimented with a ...
# ..                                                 ...
# 118                                        Citations\n
# 119                                            Books\n
# 120                                     Publications\n
# 121                                         Journals\n
# 122                                            Video\n
#
# [123 rows x 1 columns]

# %% [markdown]
# exploring dataframe

# %%
df.head()
# Out:
#                                           Paragraphs
# 0                                                 \n
# 1  Nikola Tesla (/ˈtɛslə/; Serbian Cyrillic: Нико...
# 2  Born and raised in the Austrian Empire, Tesla ...
# 3  Attempting to develop inventions he could pate...
# 4  After Wardenclyffe, Tesla experimented with a ...

# %% [markdown]
# exploring number of rows and columns

# %%
df.shape
# Out:
# (123, 1)

# %% [markdown]
# extracting hyperlink from webpage

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_wikipedia_hyperlinks(url):
    # Send a GET request to the Wikipedia page
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract text fields with hyperlinks
        links_data = []
        for link in soup.find_all('a', href=True):
            link_text = link.text.strip()
            link_href = link['href'].strip()
            if link_text:
                links_data.append({'Text': link_text, 'Link': link_href})

        return links_data
    else:
        # If the request was not successful, print an error message
        print(f"Error: Unable to fetch the page. Status code: {response.status_code}")
        return None

# Load the extracted data into a Pandas DataFrame
def create_dataframe(data):
    df = pd.DataFrame(data, columns=['Text', 'Link'])
    return df

# Example usage
if __name__ == "__main__":

    wikipedia_url = 'https://en.wikipedia.org/wiki/Nikola_Tesla'

    # Run the scraping function
    links_data = scrape_wikipedia_hyperlinks(wikipedia_url)

    if links_data:
        # Load the data into a Pandas DataFrame
        df = create_dataframe(links_data)

        # Print the DataFrame
        print("DataFrame:")
        print(df)
    else:
        print("Scraping failed.")
# Out:
# DataFrame:
#                   Text                                               Link
# 0      Jump to content                                       #bodyContent
# 1            Main page                                    /wiki/Main_Page
# 2             Contents                           /wiki/Wikipedia:Contents
# 3       Current events                        /wiki/Portal:Current_events
# 4       Random article                               /wiki/Special:Random
# ...                ...                                                ...
# 2551   Code of Conduct  https://foundation.wikimedia.org/wiki/Special:...
# 2552        Developers                    https://developer.wikimedia.org
# 2553        Statistics     https://stats.wikimedia.org/#/en.wikipedia.org
# 2554  Cookie statement  https://foundation.wikimedia.org/wiki/Special:...
# 2555       Mobile view  //en.m.wikipedia.org/w/index.php?title=Nikola_...
#
# [2556 rows x 2 columns]

# %% [markdown]
# data visualization

# %%
df.head(10)
# Out:
#               Text                                               Link
# 0  Jump to content                                       #bodyContent
# 1        Main page                                    /wiki/Main_Page
# 2         Contents                           /wiki/Wikipedia:Contents
# 3   Current events                        /wiki/Portal:Current_events
# 4   Random article                               /wiki/Special:Random
# 5  About Wikipedia                              /wiki/Wikipedia:About
# 6       Contact us       //en.wikipedia.org/wiki/Wikipedia:Contact_us
# 7           Donate  https://donate.wikimedia.org/wiki/Special:Fund...
# 8             Help                                /wiki/Help:Contents
# 9    Learn to edit                            /wiki/Help:Introduction
# No charts were generated by quickchart

# %%
df.tail(5)
# Out:
#                   Text                                               Link
# 2551   Code of Conduct  https://foundation.wikimedia.org/wiki/Special:...
# 2552        Developers                    https://developer.wikimedia.org
# 2553        Statistics     https://stats.wikimedia.org/#/en.wikipedia.org
# 2554  Cookie statement  https://foundation.wikimedia.org/wiki/Special:...
# 2555       Mobile view  //en.m.wikipedia.org/w/index.php?title=Nikola_...
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('Text').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_13.groupby('Link').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
df.shape
# Out:
# (2556, 2)

# %%
pd.isnull(df)
# Out:
#        Text   Link
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ...     ...    ...
# 2551  False  False
# 2552  False  False
# 2553  False  False
# 2554  False  False
# 2555  False  False
#
# [2556 rows x 2 columns]
# No charts were generated by quickchart
